# %%
import importlib, corrida_analisis as ca
importlib.reload(ca)

model = ca.load_cost_model_from_excel("costos_estimados.ods")
model
# Out:
# DetailedCostModel(years=array([1, 2, 3, 4, 5]), volume=array([32640., 34680., 36720., 38760., 38760.]), price_net=array([147.6127451 , 153.92041522, 156.80392157, 156.2879257 ,
#        156.2879257 ]), ingresos_principales=array([4798080., 5097960., 5397840., 5697720., 5697720.]), ingresos_adicionales=array([ 20000., 240000., 360000., 360000., 360000.]), total_ingresos=array([4818080., 5337960., 5757840., 6057720., 6057720.]), var_cost_unit=48.2835503921569, fixed_cost_annual=606192.0, discount_rate=0.0777, capex_initial=881379.0, depreciation_annual=0.0)
